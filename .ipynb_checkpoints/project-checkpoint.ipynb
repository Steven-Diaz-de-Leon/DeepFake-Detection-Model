# %% [markdown]
# ### List modules

# %%
import numpy as np
import os
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
import warnings
import json
import glob
import pickle
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Data

# %%
with open("variables/train_size", 'rb') as f:
    train_size = pickle.load(f)
with open("variables/test_size", 'rb') as f:
    test_size = pickle.load(f)  
print("Train samples: ", train_size)
print("Test samples: ", test_size)
# Out:
# Train samples:  401
# Test samples:  400

# %% [markdown]
# ### File extensions and count

# %%
with open("variables/train_list", 'rb') as f:
    train_list = pickle.load(f)
with open("variables/ext_dict", 'rb') as f:
    ext_dict = pickle.load(f)
 
print("Extensions: ", ext_dict)      


for file_ext in ext_dict:
    print("Files with extension ",file_ext, ": ", len([file for file in train_list if  file.endswith(file_ext)]))
# Out:
# Extensions:  ['mp4', 'json']
# Files with extension  mp4 :  400
# Files with extension  json :  1

# %% [markdown]
# # Checking json file
# <img src="files/labels.png">

# %% [markdown]
# #### ^^ All missing data has in original is associated with the label REAL (Real videos are the originals)

# %% [markdown]
# # Plot data distribution
# <img src="files/plot data.png">

# %%
# !pip install facenet-pytorch
# Out:
# Requirement already satisfied: facenet-pytorch in /home/deathwish/anaconda3/lib/python3.8/site-packages (2.5.2)
# Requirement already satisfied: numpy in /home/deathwish/.local/lib/python3.8/site-packages (from facenet-pytorch) (1.19.5)
# Requirement already satisfied: torchvision in /home/deathwish/.local/lib/python3.8/site-packages (from facenet-pytorch) (0.9.1)
# Requirement already satisfied: requests in /home/deathwish/anaconda3/lib/python3.8/site-packages (from facenet-pytorch) (2.24.0)
# Requirement already satisfied: pillow in /home/deathwish/anaconda3/lib/python3.8/site-packages (from facenet-pytorch) (7.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/deathwish/anaconda3/lib/python3.8/site-packages (from requests->facenet-pytorch) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/deathwish/anaconda3/lib/python3.8/site-packages (from requests->facenet-pytorch) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/deathwish/anaconda3/lib/python3.8/site-packages (from requests->facenet-pytorch) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /home/deathwish/anaconda3/lib/python3.8/site-packages (from requests->facenet-pytorch) (2.10)
# Requirement already satisfied: torch==1.8.1 in /home/deathwish/.local/lib/python3.8/site-packages (from torchvision->facenet-pytorch) (1.8.1)
# Requirement already satisfied: typing-extensions in /home/deathwish/.local/lib/python3.8/site-packages (from torch==1.8.1->torchvision->facenet-pytorch) (3.7.4.3)

# %%
class DetectionPipeline:

    def __init__(self, detector, n_frames=None, batch_size=60, resize=None):

        self.detector = detector
        self.n_frames = n_frames
        self.batch_size = batch_size
        self.resize = resize
        
            
    def __call__(self, filename):
 
   
        v_cap = cv2.VideoCapture(filename)
        v_len = int(v_cap.get(cv2.CAP_PROP_FRAME_COUNT))
        print(v_len)
    
        if self.n_frames is None:
            sample = np.arange(0, v_len)
        else:
            sample = np.linspace(0, v_len - 1, self.n_frames).astype(int)

   
        faces = []
        frames = []
        for j in range(v_len):
            success = v_cap.grab()
            if j in sample:
    
                success, frame = v_cap.retrieve()
                if not success:
                    continue
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                frame = Image.fromarray(frame)
                
    
                if self.resize is not None:
                    frame = frame.resize([int(d * self.resize) for d in frame.size])
                frames.append(frame)

   
                if len(frames) % self.batch_size == 0 or j == sample[-1]:
                    faces.extend(self.detector(frames))
                    frames = []

        v_cap.release()
        
        return faces

# %%
import copy
def process_faces(faces, resnet):

    faces = [f for f in faces if f is not None]
    if(len(faces) == 0):
        return []

    faces = torch.cat(faces).to(device)
    if(len(faces)<290):
        return []

    faces = faces[:290]

    embeddings = resnet(faces)

    centroid = embeddings.mean(dim=0)
    
    x = (embeddings - centroid).norm(dim=1).cpu().numpy()
    
    return x

# %%
#detection_pipeline = DetectionPipeline(detector=mtcnn, batch_size=60, resize=0.25)
#import json

#with open('/content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/metadata.json') as f:
#  data = json.load(f)

#filenames = glob.glob('/content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/*.mp4')
#total_files = len(filenames)

#X = []
#y = []
#start = time.time()
#n_processed = 0

#with torch.no_grad():
#  for i, filename in tqdm(enumerate(filenames), total=len(filenames)):
#    print(i, filename)
#    faces = detection_pipeline(filename)
#    z = process_faces(faces, resnet)
#    if len(z)!=0:
#      X.append(z)
#      if data[filename[87:]]['label'] == 'FAKE':
#        y.append(1)
#      else:
#        y.append(0)
#    n_processed += len(faces)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# 0 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cffffbcywc.mp4
# 300
# /usr/local/lib/python3.7/dist-packages/facenet_pytorch/models/utils/detect_face.py:183: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   batch_boxes, batch_points = np.array(batch_boxes), np.array(batch_points)
# /usr/local/lib/python3.7/dist-packages/facenet_pytorch/models/mtcnn.py:339: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   boxes = np.array(boxes)
# /usr/local/lib/python3.7/dist-packages/facenet_pytorch/models/mtcnn.py:340: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   probs = np.array(probs)
# /usr/local/lib/python3.7/dist-packages/facenet_pytorch/models/mtcnn.py:341: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   points = np.array(points)
# 1 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cxrfacemmq.mp4
# 300
# 2 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cwsbspfzck.mp4
# 300
# 3 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/coadfnerlk.mp4
# 300
# 4 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cxfujlvsuw.mp4
# 300
# 5 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cycacemkmt.mp4
# 300
# 6 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/czkdanyadc.mp4
# 300
# 7 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dakqwktlbi.mp4
# 300
# 8 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dakiztgtnw.mp4
# 300
# 9 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dbhrpizyeq.mp4
# 298
# 10 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/czfunozvwp.mp4
# 300
# 11 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dbhoxkblzx.mp4
# 300
# 12 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dafhtipaml.mp4
# 300
# 13 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/czmqpxrqoh.mp4
# 300
# 14 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cettndmvzl.mp4
# 300
# 15 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cyxlcuyznd.mp4
# 300
# 16 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cvaksbpssm.mp4
# 300
# 17 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cyclgfjdrv.mp4
# 300
# 18 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cxttmymlbn.mp4
# 300
# 19 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cyboodqqyr.mp4
# 300
# 20 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dbzcqmxzaj.mp4
# 300
# 21 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dcuiiorugd.mp4
# 300
# 22 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dcamvmuors.mp4
# 300
# 23 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dbnygxtwek.mp4
# 300
# 24 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dbzpcjntve.mp4
# 300
# 25 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/brvqtabyxj.mp4
# 300
# 26 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dbtbbhakdv.mp4
# 300
# 27 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dboxtiehng.mp4
# 300
# 28 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ddqccgmtka.mp4
# 300
# 29 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ddpvuimigj.mp4
# 300
# 30 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ddjggcasdw.mp4
# 300
# 31 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/crktehraph.mp4
# 300
# 32 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cqhngvpgyi.mp4
# 300
# 33 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ddhfabwpuz.mp4
# 300
# 34 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bxzakyopjf.mp4
# 300
# 35 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ddepeddixj.mp4
# 298
# 36 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cwqlvzefpg.mp4
# 300
# 37 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cobjrlugvp.mp4
# 300
# 38 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dgmevclvzy.mp4
# 300
# 39 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/degpbqvcay.mp4
# 300
# 40 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dfbpceeaox.mp4
# 300
# 41 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/deyyistcrd.mp4
# 300
# 42 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/deywhkarol.mp4
# 300
# 43 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cdaxixbosp.mp4
# 300
# 44 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dhjmzhrcav.mp4
# 300
# 45 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dhevettufk.mp4
# 298
# 46 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dhcselezer.mp4
# 300
# 47 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dhcndnuwta.mp4
# 300
# 48 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/avgiuextiz.mp4
# 300
# 49 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dgzklxjmix.mp4
# 300
# 50 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dgxrqjdomn.mp4
# 300
# 51 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/diqraixiov.mp4
# 300
# 52 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dhoqofwoxa.mp4
# 300
# 53 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dhkwmjxwrn.mp4
# 300
# 54 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/diopzaywor.mp4
# 300
# 55 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/diomeixhrg.mp4
# 300
# 56 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dhxctgyoqj.mp4
# 300
# 57 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cwrtyzndpx.mp4
# 300
# 58 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/djxdyjopjd.mp4
# 300
# 59 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/djvutyvaio.mp4
# 300
# 60 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/djvtbgwdcc.mp4
# 300
# 61 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/diuzrpqjli.mp4
# 300
# 62 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dkwjwbwgey.mp4
# 300
# 63 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dkhlttuvmx.mp4
# 300
# 64 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dkuayagnmc.mp4
# 300
# 65 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bsfmwclnqy.mp4
# 300
# 66 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ckkuyewywx.mp4
# 300
# 67 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dkrvorliqc.mp4
# 300
# 68 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dkdwxmtpuo.mp4
# 300
# 69 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dlrsbscitn.mp4
# 300
# 70 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dnexlwbcxq.mp4
# 300
# 71 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dlpoieqvfb.mp4
# 300
# 72 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dkzvdrzcnr.mp4
# 300
# 73 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dntkzzzcdh.mp4
# 300
# 74 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dptbnjnkdg.mp4
# 300
# 75 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dozyddhild.mp4
# 298
# 76 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dofusvhnib.mp4
# 300
# 77 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/doanjploai.mp4
# 300
# 78 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dnyvfblxpm.mp4
# 300
# 79 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dnhvalzvrt.mp4
# 300
# 80 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dqppxmoqdl.mp4
# 300
# 81 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dqnyszdong.mp4
# 300
# 82 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dqzreruvje.mp4
# 300
# 83 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dqswpjoepo.mp4
# 300
# 84 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dptrzdvwpg.mp4
# 300
# 85 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dqqtjcryjv.mp4
# 300
# 86 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dsgpbgsrdm.mp4
# 300
# 87 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/drcyabprvt.mp4
# 300
# 88 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dsdoseflas.mp4
# 300
# 89 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/drtbksnpol.mp4
# 300
# 90 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/drsakwyvqv.mp4
# 300
# 91 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/drgjzlxzxj.mp4
# 300
# 92 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dulanfulol.mp4
# 300
# 93 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dsjbknkujw.mp4
# 300
# 94 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dubiroskqn.mp4
# 300
# 95 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dtocdfbwca.mp4
# 300
# 96 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dtbpmdqvao.mp4
# 300
# 97 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dsndhujjjb.mp4
# 300
# 98 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/duycddgtrl.mp4
# 300
# 99 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dvumqqhoac.mp4
# 300
# 100 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/duvyaxbzvp.mp4
# 300
# 101 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dvakowbgbt.mp4
# 300
# 102 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/duzuusuajr.mp4
# 300
# 103 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dxbqjxrhin.mp4
# 300
# 104 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dzqwgqewhu.mp4
# 300
# 105 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dzieklokdr.mp4
# 300
# 106 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dwediigjit.mp4
# 300
# 107 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dxuplhwvig.mp4
# 300
# 108 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dxuliowugt.mp4
# 300
# 109 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ebchwmwayp.mp4
# 300
# 110 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dzwkmcwkwl.mp4
# 300
# 111 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eajlrktemq.mp4
# 300
# 112 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dzvyfiarrq.mp4
# 300
# 113 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eahlqmfvtj.mp4
# 300
# 114 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/dzyuwjkjui.mp4
# 300
# 115 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ecnihjlfyt.mp4
# 300
# 116 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eckvhdusax.mp4
# 300
# 117 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ebebgmtlcu.mp4
# 300
# 118 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ebywfrmhtd.mp4
# 300
# 119 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ebkzwjgjhq.mp4
# 300
# 120 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ebeknhudxq.mp4
# 300
# 121 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eebrkicpry.mp4
# 300
# 122 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ecwaxgutkc.mp4
# 300
# 123 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ecujsjhscd.mp4
# 300
# 124 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/edyncaijwx.mp4
# 300
# 125 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eczrseixwq.mp4
# 300
# 126 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ecuvtoltue.mp4
# 300
# 127 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eebserckhh.mp4
# 300
# 128 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ckbdwedgmc.mp4
# 300
# 129 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/efdyrflcpg.mp4
# 300
# 130 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eeyhxisdfh.mp4
# 300
# 131 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eepezmygaq.mp4
# 300
# 132 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eekozbeafq.mp4
# 300
# 133 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eejswgycjc.mp4
# 300
# 134 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/egghxjjmfg.mp4
# 300
# 135 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ehbnclaukr.mp4
# 300
# 136 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/efwfxwwlbw.mp4
# 300
# 137 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eggbjzxnmg.mp4
# 300
# 138 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/egbbcxcuqy.mp4
# 300
# 139 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ehtdtkmmli.mp4
# 300
# 140 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ehccixxzoe.mp4
# 300
# 141 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ehieahnhte.mp4
# 300
# 142 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ehfiekigla.mp4
# 300
# 143 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ehevsxtecd.mp4
# 300
# 144 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ehdkmxgtxh.mp4
# 300
# 145 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eivxffliio.mp4
# 300
# 146 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ejkqesyvam.mp4
# 300
# 147 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eiriyukqqy.mp4
# 300
# 148 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eixwxvxbbn.mp4
# 300
# 149 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eiwopxzjfn.mp4
# 300
# 150 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/elvvackpjh.mp4
# 300
# 151 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ekhacizpah.mp4
# 300
# 152 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ellavthztb.mp4
# 300
# 153 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/elginszwtk.mp4
# 300
# 154 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ekkdjkirzq.mp4
# 300
# 155 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ekcrtigpab.mp4
# 300
# 156 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eprybmbpba.mp4
# 300
# 157 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eoewqcpbgt.mp4
# 300
# 158 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/emaalmsonj.mp4
# 300
# 159 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ensyyivobf.mp4
# 300
# 160 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/emgjphonqb.mp4
# 300
# 161 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/emfbhytfhc.mp4
# 300
# 162 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/erqgqacbqe.mp4
# 300
# 163 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eqjscdagiv.mp4
# 300
# 164 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/caqbrkogkb.mp4
# 300
# 165 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/epymyyiblu.mp4
# 300
# 166 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cqrskwiqng.mp4
# 300
# 167 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/erlvuvjsjf.mp4
# 300
# 168 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cgvrgibpfo.mp4
# 300
# 169 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eqvuznuwsa.mp4
# 300
# 170 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eqnoqyfquo.mp4
# 300
# 171 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/esckbnkkvb.mp4
# 300
# 172 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/esyhwdfnxs.mp4
# 300
# 173 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/esxrvsgpvb.mp4
# 300
# 174 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/btugrnoton.mp4
# 300
# 175 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/esnntzzajv.mp4
# 298
# 176 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/esgftaficx.mp4
# 300
# 177 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/errocgcham.mp4
# 300
# 178 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/etohcvnzbj.mp4
# 300
# 179 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/etdcqxabww.mp4
# 300
# 180 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/esyrimvzsa.mp4
# 300
# 181 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/etmcruaihe.mp4
# 300
# 182 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/etejaapnxh.mp4
# 300
# 183 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eukvucdetx.mp4
# 300
# 184 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/eudeqjhdfd.mp4
# 300
# 185 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bpapbctoao.mp4
# 300
# 186 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bvzjkezkms.mp4
# 300
# 187 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/byyqectxqa.mp4
# 300
# 188 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cpjxareypw.mp4
# 300
# 189 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aapnvogymq.mp4
# 300
# 190 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aagfhgtpmv.mp4
# 300
# 191 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/acxnxvbsxk.mp4
# 300
# 192 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/acqfdwsrhi.mp4
# 300
# 193 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/acifjvzvpm.mp4
# 300
# 194 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/abqwwspghj.mp4
# 300
# 195 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/abarnvbtwb.mp4
# 300
# 196 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/abofeumbvv.mp4
# 300
# 197 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/adhsbajydo.mp4
# 300
# 198 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aczrgyricp.mp4
# 300
# 199 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/adylbeequz.mp4
# 300
# 200 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/acxwigylke.mp4
# 298
# 201 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/adohikbdaz.mp4
# 300
# 202 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aelfnikyqj.mp4
# 300
# 203 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aettqgevhz.mp4
# 300
# 204 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/afoovlsmtx.mp4
# 300
# 205 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aelzhcnwgf.mp4
# 300
# 206 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aevrfsexku.mp4
# 300
# 207 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/agdkmztvby.mp4
# 300
# 208 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/agqphdxmwt.mp4
# 300
# 209 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ahbweevwpv.mp4
# 300
# 210 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/agrmhtjdlk.mp4
# 300
# 211 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ahfazfbntc.mp4
# 300
# 212 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ahdbuwqxit.mp4
# 300
# 213 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ahqqqilsxt.mp4
# 300
# 214 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aipfdnwpoo.mp4
# 300
# 215 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aknbdpmgua.mp4
# 300
# 216 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ajwpjhrbcv.mp4
# 300
# 217 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ajqslcypsw.mp4
# 300
# 218 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aklqzsddfl.mp4
# 300
# 219 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aknmpoonls.mp4
# 300
# 220 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/akvmwkdyuv.mp4
# 300
# 221 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/akxoopqjqz.mp4
# 300
# 222 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/alaijyygdv.mp4
# 298
# 223 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aladcziidp.mp4
# 298
# 224 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/akzbnazxtz.mp4
# 300
# 225 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/altziddtxi.mp4
# 300
# 226 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/alvgwypubw.mp4
# 300
# 227 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/alninxcyhg.mp4
# 300
# 228 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/andaxzscny.mp4
# 300
# 229 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/amowujxmzc.mp4
# 300
# 230 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/amaivqofda.mp4
# 300
# 231 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aorjvbyxhw.mp4
# 300
# 232 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/anpuvshzoo.mp4
# 300
# 233 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aneclqfpbt.mp4
# 300
# 234 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aqpnvjhuzw.mp4
# 300
# 235 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/arlmiizoob.mp4
# 300
# 236 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/apogckdfrz.mp4
# 300
# 237 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/arkroixhey.mp4
# 300
# 238 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/apatcsqejh.mp4
# 300
# 239 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/apgjqzkoma.mp4
# 300
# 240 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/asvcrfdpnq.mp4
# 300
# 241 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/asmpfjfzif.mp4
# 300
# 242 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/arrhsnjqku.mp4
# 300
# 243 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/asdpeebotb.mp4
# 300
# 244 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/asaxgevnnp.mp4
# 300
# 245 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aslsvlvpth.mp4
# 300
# 246 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/atvmxvwyns.mp4
# 300
# 247 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/atkdltyyen.mp4
# 300
# 248 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/atxvxouljq.mp4
# 300
# 249 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/atyntldecu.mp4
# 300
# 250 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/atzdznmder.mp4
# 300
# 251 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aufmsmnoye.mp4
# 300
# 252 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/avfitoutyn.mp4
# 300
# 253 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/avibnnhwhp.mp4
# 300
# 254 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/augtsuxpzc.mp4
# 300
# 255 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/avnqydkqjj.mp4
# 300
# 256 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/avvdgsennp.mp4
# 300
# 257 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/avssvvsdhz.mp4
# 300
# 258 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/avtycwsgyb.mp4
# 300
# 259 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/avmjormvsx.mp4
# 300
# 260 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/axczxisdtb.mp4
# 300
# 261 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/avywawptfc.mp4
# 300
# 262 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/awukslzjra.mp4
# 300
# 263 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/awhmfnnjih.mp4
# 300
# 264 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/awnwkrqibf.mp4
# 300
# 265 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/axwgcsyphv.mp4
# 300
# 266 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/axoygtekut.mp4
# 298
# 267 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/axwovszumc.mp4
# 300
# 268 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/axntxmycwd.mp4
# 300
# 269 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aytzyidmgs.mp4
# 300
# 270 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ayqvfdhslr.mp4
# 300
# 271 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aybgughjxh.mp4
# 300
# 272 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/aybumesmpk.mp4
# 300
# 273 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/azpuxunqyo.mp4
# 300
# 274 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bahdpoesir.mp4
# 300
# 275 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bbhpvrmbse.mp4
# 300
# 276 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/azsmewqghg.mp4
# 300
# 277 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bchnbulevv.mp4
# 300
# 278 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bddjdhzfze.mp4
# 300
# 279 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bbhtdfuqxq.mp4
# 300
# 280 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bctvsmddgq.mp4
# 300
# 281 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bdbhekrrwo.mp4
# 300
# 282 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bbvgxeczei.mp4
# 300
# 283 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bdxuhamuqx.mp4
# 300
# 284 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bdgipnyobr.mp4
# 300
# 285 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bdnaqemxmr.mp4
# 300
# 286 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/beboztfcme.mp4
# 298
# 287 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/benmsfzfaz.mp4
# 300
# 288 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bejhvclboh.mp4
# 300
# 289 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/beyebyhrph.mp4
# 300
# 290 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bghphrsfxf.mp4
# 300
# 291 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bggsurpgpr.mp4
# 300
# 292 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bffwsjxghk.mp4
# 300
# 293 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bgaogsjehq.mp4
# 300
# 294 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bguwlyazau.mp4
# 300
# 295 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bgmlwsoamc.mp4
# 300
# 296 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bhaaboftbc.mp4
# 300
# 297 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bhpwpydzpo.mp4
# 300
# 298 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bhbdugnurr.mp4
# 300
# 299 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bgwmmujlmc.mp4
# 300
# 300 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bgvhtpzknn.mp4
# 300
# 301 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bjkmjilrxp.mp4
# 300
# 302 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bjsmaqefoi.mp4
# 300
# 303 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bjjbwsqjir.mp4
# 300
# 304 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bhsluedavd.mp4
# 300
# 305 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bilnggbxgu.mp4
# 300
# 306 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bkmdzhfzfh.mp4
# 300
# 307 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/blzydqdfem.mp4
# 300
# 308 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bkvetcojbt.mp4
# 300
# 309 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/blpchvmhxx.mp4
# 300
# 310 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bkwxhglwct.mp4
# 300
# 311 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bmbbkwmxqj.mp4
# 300
# 312 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bmehkyanbj.mp4
# 300
# 313 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bmioepcpsx.mp4
# 300
# 314 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bmjmjmbglm.mp4
# 300
# 315 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bmjzrlszhi.mp4
# 300
# 316 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bmhvktyiwp.mp4
# 300
# 317 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bntlodcfeg.mp4
# 300
# 318 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bofqajtwve.mp4
# 300
# 319 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bndybcqhfr.mp4
# 300
# 320 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bnjcdrfuov.mp4
# 300
# 321 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bnbuonyoje.mp4
# 300
# 322 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/boovltmuwi.mp4
# 300
# 323 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bourlmzsio.mp4
# 300
# 324 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bopqhhalml.mp4
# 300
# 325 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bqeiblbxtl.mp4
# 300
# 326 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bqdjzqhcft.mp4
# 300
# 327 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bpwzipqtxf.mp4
# 300
# 328 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bqkdbcqjvb.mp4
# 300
# 329 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bpxckdzddv.mp4
# 300
# 330 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bqhtpqmmqp.mp4
# 300
# 331 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bqtuuwzdtr.mp4
# 300
# 332 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bqqpbzjgup.mp4
# 300
# 333 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bqnymlsayl.mp4
# 300
# 334 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/brhalypwoo.mp4
# 300
# 335 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bseamdrpbj.mp4
# 300
# 336 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/btiysiskpf.mp4
# 300
# 337 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bsqgziaylx.mp4
# 300
# 338 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/brwrlczjvi.mp4
# 300
# 339 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/btjlfpzbdu.mp4
# 300
# 340 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/btjwbtsgln.mp4
# 300
# 341 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/btohlidmru.mp4
# 300
# 342 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/btmsngnqhv.mp4
# 300
# 343 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/btxlttbpkj.mp4
# 300
# 344 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bulkxhhknf.mp4
# 300
# 345 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/btunxncpjh.mp4
# 300
# 346 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bwipwzzxxu.mp4
# 300
# 347 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bwhlgysghg.mp4
# 300
# 348 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bvgwelbeof.mp4
# 300
# 349 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bweezhfpzp.mp4
# 300
# 350 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bwuwstvsbw.mp4
# 300
# 351 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/byfenovjnf.mp4
# 300
# 352 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bydaidkpdp.mp4
# 300
# 353 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/byunigvnay.mp4
# 300
# 354 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/byofowlkki.mp4
# 300
# 355 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/byijojkdba.mp4
# 298
# 356 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/byqzyxifza.mp4
# 300
# 357 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/caifxvsozs.mp4
# 300
# 358 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bzmdrafeex.mp4
# 300
# 359 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/bzythlfnhq.mp4
# 300
# 360 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cbbibzcoih.mp4
# 300
# 361 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ccfoszqabv.mp4
# 300
# 362 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cbltdtxglo.mp4
# 300
# 363 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cdbsbdymzd.mp4
# 300
# 364 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ccmonzqfrz.mp4
# 300
# 365 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cdphtzqrvp.mp4
# 300
# 366 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cepxysienc.mp4
# 300
# 367 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cdyakrxkia.mp4
# 300
# 368 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cferslmfwh.mp4
# 300
# 369 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cfxkpiweqt.mp4
# 300
# 370 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ceymbecxnj.mp4
# 300
# 371 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cfyduhpbps.mp4
# 300
# 372 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/chtapglbcj.mp4
# 300
# 373 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cglxirfaey.mp4
# 300
# 374 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/chviwxsfhg.mp4
# 300
# 375 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/chzieimrwu.mp4
# 298
# 376 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ckjaibzfxa.mp4
# 300
# 377 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ciyoudyhly.mp4
# 300
# 378 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cizlkenljw.mp4
# 300
# 379 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cknyxaqouy.mp4
# 300
# 380 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cmbzllswnl.mp4
# 300
# 381 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/clihsshdkq.mp4
# 300
# 382 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/clrycekyst.mp4
# 300
# 383 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cksanfsjhc.mp4
# 300
# 384 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cnilkgvfei.mp4
# 300
# 385 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/covdcysmbi.mp4
# 300
# 386 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cmxcfkrjiv.mp4
# 300
# 387 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cppdvdejkc.mp4
# 298
# 388 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cprhtltsjp.mp4
# 300
# 389 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cqfugiqupm.mp4
# 300
# 390 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/crzfebnfgb.mp4
# 300
# 391 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/crezycjqyk.mp4
# 300
# 392 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cthdnahrkh.mp4
# 300
# 393 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ctpqeykqdp.mp4
# 300
# 394 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cttqtsjvgn.mp4
# 300
# 395 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/curpwogllm.mp4
# 300
# 396 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/ctzmavwror.mp4
# 300
# 397 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cwbacdwrzo.mp4
# 300
# 398 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cuzrgrbvil.mp4
# 300
# 399 /content/drive/Shared drives/deepfake/deepfake-detection-challenge/train_sample_videos/cwwandrkus.mp4
# 300

# %%
with open("variables/casiaX", 'rb') as f:
    casiaX = pickle.load(f)
with open("variables/casiaY", 'rb') as f:
    casiaY = pickle.load(f)

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/deathwish/anaconda3/lib/python3.8/site-packages (0.24.2)
# Requirement already satisfied: joblib>=0.11 in /home/deathwish/.local/lib/python3.8/site-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/deathwish/anaconda3/lib/python3.8/site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /home/deathwish/anaconda3/lib/python3.8/site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/deathwish/.local/lib/python3.8/site-packages (from scikit-learn) (1.19.5)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn import svm
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(casiaX, casiaY, test_size=0.85, random_state=5)

# %%
clf = LogisticRegression(random_state=0).fit(X_train, y_train)
y_pred_lr = clf.predict(X_test)
print("Logisitic Regression: ", accuracy_score(y_test,y_pred_lr))
# Out:
# Logisitic Regression:  0.8012820512820513

# %%
gnb = GaussianNB()
y_pred_gnb = gnb.fit(X_train, y_train).predict(X_test)
print("GaussianNB:", accuracy_score(y_test,y_pred_gnb))
# Out:
# GaussianNB: 0.6410256410256411

# %%
clf = svm.SVC(gamma='auto')
clf.fit(X_train, y_train)
y_pred_svm = clf.predict(X_test)
print("SVM: ",accuracy_score(y_test,y_pred_svm))
# Out:
# SVM:  0.8076923076923077

# %%
# Out:
# SVM:  0.8076923076923077

# %%
#using VGGFace2
# %cache X1=X[1:]
with open("VGGX", 'wb') as f:
    pickle.dump(X1, f)
# %cache y1=y[1:]
with open("VGGY", 'wb') as f:
    pickle.dump(y1, f)
# Out:
# Loading cached value for variable 'X1'. Time since caching: 22:15:12.970218
# Loading cached value for variable 'y1'. Time since caching: 22:15:13.723775

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.85, random_state=5)

clf = LogisticRegression(random_state=0).fit(X_train, y_train)
y_pred_lr = clf.predict(X_test)
print("Logisitic Regression: ", accuracy_score(y_test,y_pred_lr))
# Out:
# Logisitic Regression:  0.8076923076923077

# %%
gnb = GaussianNB()
y_pred_gnb = gnb.fit(X_train, y_train).predict(X_test)
print("GaussianNB:", accuracy_score(y_test,y_pred_gnb))
# Out:
# GaussianNB: 0.6826923076923077

# %%
clf = svm.SVC(gamma='auto')
clf.fit(X_train, y_train)
y_pred_svm = clf.predict(X_test)
print("SVM: ",accuracy_score(y_test,y_pred_svm))
# Out:
# SVM:  0.8076923076923077
